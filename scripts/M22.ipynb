# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
d='../../../../../Downloads/'
f1=np.loadtxt(d+'M22_1.txt') # 1 star, siblings, similar to one belo
f7=np.loadtxt(d+'M22_7.txt') # li-rich one in M22 (belongs to s-process group)

# low-res , high-snr
# another pair with higher snr


# 4 stars at low-res, similar SNR
# 3 stars at lower res

# m22 has 2 sprocess groups

# less-payne process the spectra (gives good continuum placement), but SMHR is where you do EW stuff
# 1. stitch
# 2. measure individual iron lines (S5 line list)
# FeH = -1.7

# %%
plt.figure(dpi=100)
plt.plot(f1[:,0],f1[:,1])
plt.plot(f7[:,0],f7[:,1])
plt.xlim(6702, 6715)
plt.ylim(-0.5,2.5)
plt.axvline(6707.8)

# %%
plt.figure(dpi=100)
plt.plot(f1[:,0],f1[:,1])
plt.plot(f7[:,0],f7[:,1])
plt.xlim(6702, 6715)
plt.ylim(-0.5,2.5)
plt.axvline(6707.8)

# %%
plt.figure(dpi=100)
plt.plot(f1[:,0],f1[:,1])
plt.plot(f7[:,0],f7[:,1])
plt.xlim(6563-5,6563+5)
plt.ylim(-0.5,2.5)
plt.axvline(6563)

# %%
plt.figure(dpi=100)
plt.plot(f1[:,0],f1[:,1])
plt.plot(f7[:,0],f7[:,1])
plt.xlim(5535.481-2,5535.481+2)
plt.ylim(0.5,1.5)
plt.axvline(5535.481)

# %%
plt.figure(dpi=100)
plt.plot(f1[:,0],f7[:,1]-f1[:,1])
plt.xlim(6563-5,6563+5)
plt.ylim(-0.5,2.5)
plt.axvline(6563)

# %%
len(f1[:,0]),len(f7[:,0])
# Out:
# (48063, 48063)

# %%
sorted_f = np.sort(f7[:,1]-f1[:,1])


plt.figure()
plt.plot(f1[:,0],f7[:,1]-f1[:,1])
plt.ylim(-1,1)
plt.xlim(5200,5600)
# plt.axvline(6707.8,c='k',)
plt.axvline(6563,c='C1')
plt.axvline(5399,c='k')
plt.axvline(5433,c='r')

# %%
plt.figure(dpi=100)
plt.plot(f1[:,0],f1[:,1])
plt.plot(f1[:,0],f7[:,1])
plt.plot(f1[:,0],f7[:,1]-f1[:,1])
plt.ylim(-0.8,1.5)
plt.xlim(5880,5915)
plt.axvline(5896,c='k',lw=1,ls='dotted')
